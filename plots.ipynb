# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 16
fig_size[1] = 5

plt.plot(np.arange(1985,2019),total_dt, color='black', label='Observed')
plt.plot(np.arange(1985,2019),june.fmean[0,:], color='crimson', label='June Forecast, Skill = '+str(skills_june[0]))
plt.fill_between(np.arange(1985,2019),june.fmean[0,:]-np.sqrt(june.fvar[0,:]),june.fmean[0,:]+np.sqrt(june.fvar[0,:]),color='crimson',alpha=0.2)
plt.plot(np.arange(1985,2019),july.fmean[0,:], color='deepskyblue', label='July Forecast, Skill = '+str(skills_july[0]))
plt.fill_between(np.arange(1985,2019),july.fmean[0,:]-np.sqrt(july.fvar[0,:]),july.fmean[0,:]+np.sqrt(july.fvar[0,:]),color='deepskyblue',alpha=0.2)
plt.plot(np.arange(1985,2019),august.fmean[0,:], color='darkviolet', label='August Forecast, Skill = '+str(skills_august[0]))
plt.fill_between(np.arange(1985,2019),august.fmean[0,:]-np.sqrt(august.fvar[0,:]),august.fmean[0,:]+np.sqrt(august.fvar[0,:]),color='darkviolet',alpha=0.2)
plt.ylabel('September SIE anomaly (x10\u2076 km\u00b2)')
plt.xlabel('Year')
plt.legend(loc='lower left')
plt.show()

plt.plot(np.arange(1985,2019),SIEs['total'][0][6:], color='black', label='Observed')
plt.plot(np.arange(1985,2019),june.fmean_rt[0,:], color='crimson', label='June Forecast, Skill = 0.41')
plt.fill_between(np.arange(1985,2019),june.fvar_rt_minus[0,:],june.fvar_rt_plus[0,:],color='crimson',alpha=0.2)
plt.plot(np.arange(1985,2019),july.fmean_rt[0,:], color='deepskyblue', label='July Forecast, Skill = 0.59')
plt.fill_between(np.arange(1985,2019),july.fvar_rt_minus[0,:],july.fvar_rt_plus[0,:],color='deepskyblue',alpha=0.2)
plt.plot(np.arange(1985,2019),august.fmean_rt[0,:], color='darkviolet', label='August Forecast, Skill = 0.68')
plt.fill_between(np.arange(1985,2019),august.fvar_rt_minus[0,:],august.fvar_rt_plus[0,:],color='darkviolet',alpha=0.2)
plt.ylabel('September SIE (x10\u2076 km\u00b2)')
plt.xlabel('Year')
#plt.legend(loc='lower left')
plt.show()

# %%
# %matplotlib inline
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 34
fig_size[1] = 12

x = np.arange(1985,2019)
fig, ax = plt.subplots(3, 3, sharex='col')
ax[0,0].plot(x, baffin_dt, color='black', label='Baffin Bay (1)')
ax[0,0].plot(x, june.fmean[8,:].squeeze(), color='crimson')#, label='June Forecast, Skill = '+str(skills_june[8]))
ax[0,0].fill_between(x,june.fmean[8,:]-np.sqrt(june.fvar[8,:]),june.fmean[8,:]+np.sqrt(june.fvar[8,:]),color='crimson',alpha=0.2)
ax[0,0].plot(x, july.fmean[8,:].squeeze(), color='deepskyblue')#, label='July Forecast, Skill = '+str(skills_july[8]))
ax[0,0].fill_between(x,july.fmean[8,:]-np.sqrt(july.fvar[8,:]),july.fmean[8,:]+np.sqrt(july.fvar[8,:]),color='deepskyblue',alpha=0.2)
ax[0,0].plot(x, august.fmean[8,:].squeeze(), color='darkviolet')#, label='August Forecast, Skill = '+str(skills_august[8]))
ax[0,0].fill_between(x,august.fmean[8,:]-np.sqrt(august.fvar[8,:]),august.fmean[8,:]+np.sqrt(august.fvar[8,:]),color='darkviolet',alpha=0.2)
#ax[0,0].legend(loc='lower left')
ax[0,1].plot(x, greenland_dt, color='black', label='Greenland Sea (2)')
ax[0,1].plot(x, june.fmean[7,:].squeeze(), color='crimson')#, label='June Forecast, Skill = '+str(skills_june[7]))
ax[0,1].fill_between(x,june.fmean[7,:]-np.sqrt(june.fvar[7,:]),june.fmean[7,:]+np.sqrt(june.fvar[7,:]),color='crimson',alpha=0.2)
ax[0,1].plot(x, july.fmean[7,:].squeeze(), color='deepskyblue')#, label='July Forecast, Skill = '+str(skills_july[7]))
ax[0,1].fill_between(x,july.fmean[7,:]-np.sqrt(july.fvar[7,:]),july.fmean[7,:]+np.sqrt(july.fvar[7,:]),color='deepskyblue',alpha=0.2)
ax[0,1].plot(x, august.fmean[7,:].squeeze(), color='darkviolet')#, label='August Forecast, Skill = '+str(skills_august[7]))
ax[0,1].fill_between(x,august.fmean[7,:]-np.sqrt(august.fvar[7,:]),august.fmean[7,:]+np.sqrt(august.fvar[7,:]),color='darkviolet',alpha=0.2)
#ax[0,1].legend(loc='lower left')
ax[0,2].plot(x, barents_dt, color='black', label='Barents Sea (3)')
ax[0,2].plot(x, june.fmean[6,:].squeeze(), color='crimson')#, label='June Forecast, Skill = '+str(skills_june[6]))
ax[0,2].fill_between(x,june.fmean[6,:]-np.sqrt(june.fvar[6,:]),june.fmean[6,:]+np.sqrt(june.fvar[6,:]),color='crimson',alpha=0.2)
ax[0,2].plot(x, july.fmean[6,:].squeeze(), color='deepskyblue')#, label='July Forecast, Skill = '+str(skills_july[6]))
ax[0,2].fill_between(x,july.fmean[6,:]-np.sqrt(july.fvar[6,:]),july.fmean[6,:]+np.sqrt(july.fvar[6,:]),color='deepskyblue',alpha=0.2)
ax[0,2].plot(x, august.fmean[6,:].squeeze(), color='darkviolet')#, label='August Forecast, Skill = '+str(skills_august[6]))
ax[0,2].fill_between(x,august.fmean[6,:]-np.sqrt(august.fvar[6,:]),august.fmean[6,:]+np.sqrt(august.fvar[6,:]),color='darkviolet',alpha=0.2)
#ax[0,2].legend(loc='lower left')
ax[1,0].plot(x, kara_dt, color='black', label='Kara Sea (4)')
ax[1,0].plot(x, june.fmean[5,:].squeeze(), color='crimson')#, label='June Forecast, Skill = '+str(skills_june[5]))
ax[1,0].fill_between(x,june.fmean[5,:]-np.sqrt(june.fvar[5,:]),june.fmean[5,:]+np.sqrt(june.fvar[5,:]),color='crimson',alpha=0.2)
ax[1,0].plot(x, july.fmean[5,:].squeeze(), color='deepskyblue')#, label='July Forecast, Skill = '+str(skills_july[5]))
ax[1,0].fill_between(x,july.fmean[5,:]-np.sqrt(july.fvar[5,:]),july.fmean[5,:]+np.sqrt(july.fvar[5,:]),color='deepskyblue',alpha=0.2)
ax[1,0].plot(x, august.fmean[5,:].squeeze(), color='darkviolet')#, label='August Forecast, Skill = '+str(skills_august[5]))
ax[1,0].fill_between(x,august.fmean[5,:]-np.sqrt(august.fvar[5,:]),august.fmean[5,:]+np.sqrt(august.fvar[5,:]),color='darkviolet',alpha=0.2)
#ax[1,0].legend(loc='lower left')
ax[1,1].plot(x, laptev_dt, color='black', label='Laptev Sea (5)')
ax[1,1].plot(x, june.fmean[4,:].squeeze(), color='crimson')#, label='June Forecast, Skill = '+str(skills_june[4]))
ax[1,1].fill_between(x,june.fmean[4,:]-np.sqrt(june.fvar[4,:]),june.fmean[4,:]+np.sqrt(june.fvar[4,:]),color='crimson',alpha=0.2)
ax[1,1].plot(x, july.fmean[4,:].squeeze(), color='deepskyblue')#, label='July Forecast, Skill = '+str(skills_july[4]))
ax[1,1].fill_between(x,july.fmean[4,:]-np.sqrt(july.fvar[4,:]),july.fmean[4,:]+np.sqrt(july.fvar[4,:]),color='deepskyblue',alpha=0.2)
ax[1,1].plot(x, august.fmean[4,:].squeeze(), color='darkviolet')#, label='August Forecast, Skill = '+str(skills_august[4]))
ax[1,1].fill_between(x,august.fmean[4,:]-np.sqrt(august.fvar[4,:]),august.fmean[4,:]+np.sqrt(august.fvar[4,:]),color='darkviolet',alpha=0.2)
#ax[1,1].legend(loc='lower left')
ax[1,2].plot(x, ESS_dt, color='black', label='East Siberian Sea (6)')
ax[1,2].plot(x, june.fmean[3,:].squeeze(), color='crimson')#, label='June Forecast, Skill = '+str(skills_june[3]))
ax[1,2].fill_between(x,june.fmean[3,:]-np.sqrt(june.fvar[3,:]),june.fmean[3,:]+np.sqrt(june.fvar[3,:]),color='crimson',alpha=0.2)
ax[1,2].plot(x, july.fmean[3,:].squeeze(), color='deepskyblue')#, label='July Forecast, Skill = '+str(skills_july[3]))
ax[1,2].fill_between(x,july.fmean[3,:]-np.sqrt(july.fvar[3,:]),july.fmean[3,:]+np.sqrt(july.fvar[3,:]),color='deepskyblue',alpha=0.2)
ax[1,2].plot(x, august.fmean[3,:].squeeze(), color='darkviolet')#, label='August Forecast, Skill = '+str(skills_august[3]))
ax[1,2].fill_between(x,august.fmean[3,:]-np.sqrt(august.fvar[3,:]),august.fmean[3,:]+np.sqrt(august.fvar[3,:]),color='darkviolet',alpha=0.2)
#ax[1,2].legend(loc='lower left')
ax[2,0].plot(x, chukchi_dt, color='black', label='Chukchi Sea (7)')
ax[2,0].plot(x, june.fmean[2,:].squeeze(), color='crimson')#, label='June Forecast, Skill = '+str(skills_june[2]))
ax[2,0].fill_between(x,june.fmean[2,:]-np.sqrt(june.fvar[2,:]),june.fmean[2,:]+np.sqrt(june.fvar[2,:]),color='crimson',alpha=0.2)
ax[2,0].plot(x, july.fmean[2,:].squeeze(), color='deepskyblue')#, label='July Forecast, Skill = '+str(skills_july[2]))
ax[2,0].fill_between(x,july.fmean[2,:]-np.sqrt(july.fvar[2,:]),july.fmean[2,:]+np.sqrt(july.fvar[2,:]),color='deepskyblue',alpha=0.2)
ax[2,0].plot(x, august.fmean[2,:].squeeze(), color='darkviolet')#, label='August Forecast, Skill = '+str(skills_august[2]))
ax[2,0].fill_between(x,august.fmean[2,:]-np.sqrt(august.fvar[2,:]),august.fmean[2,:]+np.sqrt(august.fvar[2,:]),color='darkviolet',alpha=0.2)
#ax[2,0].legend(loc='lower left')
ax[2,1].plot(x, beaufort_dt, color='black', label='Beaufort Sea (8)')
ax[2,1].plot(x, june.fmean[1,:].squeeze(), color='crimson')#, label='June Forecast')#, Skill = '+str(skills_june[1]))
ax[2,1].fill_between(x,june.fmean[1,:]-np.sqrt(june.fvar[1,:]),june.fmean[1,:]+np.sqrt(june.fvar[1,:]),color='crimson',alpha=0.2)
ax[2,1].plot(x, july.fmean[1,:].squeeze(), color='deepskyblue')#, label='July Forecast')#, Skill = '+str(skills_july[1]))
ax[2,1].fill_between(x,july.fmean[1,:]-np.sqrt(july.fvar[1,:]),july.fmean[1,:]+np.sqrt(july.fvar[1,:]),color='deepskyblue',alpha=0.2)
ax[2,1].plot(x, august.fmean[1,:].squeeze(), color='darkviolet')#, label='August Forecast')#, Skill = '+str(skills_august[1]))
ax[2,1].fill_between(x,august.fmean[1,:]-np.sqrt(august.fvar[1,:]),august.fmean[1,:]+np.sqrt(august.fvar[1,:]),color='darkviolet',alpha=0.2)
#ax[2,1].legend(loc='lower left')
ax[2,2].plot(x, CA_dt, color='black', label='Canadian Arch (9)')
ax[2,2].plot(x, june.fmean[9,:].squeeze(), color='crimson')#, label='June Forecast, Skill = '+str(skills_june[9]))
ax[2,2].fill_between(x,june.fmean[9,:]-np.sqrt(june.fvar[9,:]),june.fmean[9,:]+np.sqrt(june.fvar[9,:]),color='crimson',alpha=0.2)
ax[2,2].plot(x, july.fmean[9,:].squeeze(), color='deepskyblue')#, label='July Forecast, Skill = '+str(skills_july[9]))
ax[2,2].fill_between(x,july.fmean[9,:]-np.sqrt(july.fvar[9,:]),july.fmean[9,:]+np.sqrt(july.fvar[9,:]),color='deepskyblue',alpha=0.2)
ax[2,2].plot(x, august.fmean[9,:].squeeze(), color='darkviolet')#, label='August Forecast, Skill = '+str(skills_august[9]))
ax[2,2].fill_between(x,august.fmean[9,:]-np.sqrt(august.fvar[9,:]),august.fmean[9,:]+np.sqrt(august.fvar[9,:]),color='darkviolet',alpha=0.2)
#ax[2,2].legend(loc='lower left')
plt.rcParams.update({'font.size': 16})
#fig.text(0.5, 0.07, 'Year', ha='center', va='center')
fig.text(0.095, 0.5, 'September Sea Ice Extent anomaly (x10\u2076 km\u00b2)', ha='center', va='center', rotation='vertical')
plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:58: RuntimeWarning: invalid value encountered in sqrt
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:70: RuntimeWarning: invalid value encountered in sqrt

# %%
# %matplotlib inline
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 34
fig_size[1] = 12

x = np.arange(1985,2019)
fig, ax = plt.subplots(3, 3, sharex='col')
ax[0,0].plot(x, SIEs['Baffin_Bay'][0][6:], color='black', label='Baffin Bay')
ax[0,0].plot(x, june.fmean_rt[8,:].squeeze(), color='crimson', label='June Forecast')
ax[0,0].fill_between(x,june.fvar_rt_minus[8,:],june.fvar_rt_plus[8,:],color='crimson',alpha=0.2)
ax[0,0].plot(x, july.fmean_rt[8,:].squeeze(), color='deepskyblue', label='July Forecast')
ax[0,0].fill_between(x,july.fvar_rt_minus[8,:],july.fvar_rt_plus[8,:],color='deepskyblue',alpha=0.2)
ax[0,0].plot(x, august.fmean_rt[8,:].squeeze(), color='darkviolet', label='August Forecast')
ax[0,0].fill_between(x,august.fvar_rt_minus[8,:],august.fvar_rt_plus[8,:],color='darkviolet',alpha=0.2)
#ax[0,0].legend(loc='lower left')
ax[0,1].plot(x, SIEs['Greenland_Sea'][0][6:], color='black', label='Greenland Sea')
ax[0,1].plot(x, june.fmean_rt[7,:].squeeze(), color='crimson', label='June Forecast')
ax[0,1].fill_between(x,june.fvar_rt_minus[7,:],june.fvar_rt_plus[7,:],color='crimson',alpha=0.2)
ax[0,1].plot(x, july.fmean_rt[7,:].squeeze(), color='deepskyblue', label='July Forecast')
ax[0,1].fill_between(x,july.fvar_rt_minus[7,:],july.fvar_rt_plus[7,:],color='deepskyblue',alpha=0.2)
ax[0,1].plot(x, august.fmean_rt[7,:].squeeze(), color='darkviolet', label='August Forecast')
ax[0,1].fill_between(x,august.fvar_rt_minus[7,:],august.fvar_rt_plus[7,:],color='darkviolet',alpha=0.2)
#ax[0,1].legend(loc='lower left')
ax[0,2].plot(x, SIEs['Barents_Sea'][0][6:], color='black', label='Barents Sea')
ax[0,2].plot(x, june.fmean_rt[6,:].squeeze(), color='crimson', label='June Forecast')
ax[0,2].fill_between(x,june.fvar_rt_minus[6,:],june.fvar_rt_plus[6,:],color='crimson',alpha=0.2)
ax[0,2].plot(x, july.fmean_rt[6,:].squeeze(), color='deepskyblue', label='July Forecast')
ax[0,2].fill_between(x,july.fvar_rt_minus[6,:],july.fvar_rt_plus[6,:],color='deepskyblue',alpha=0.2)
ax[0,2].plot(x, august.fmean_rt[6,:].squeeze(), color='darkviolet', label='August Forecast')
ax[0,2].fill_between(x,august.fvar_rt_minus[6,:],august.fvar_rt_plus[6,:],color='darkviolet',alpha=0.2)
#ax[0,2].legend(loc='lower left')
ax[1,0].plot(x, SIEs['Kara_Sea'][0][6:], color='black', label='Kara Sea')
ax[1,0].plot(x, june.fmean_rt[5,:].squeeze(), color='crimson', label='June Forecast')
ax[1,0].fill_between(x,june.fvar_rt_minus[5,:],june.fvar_rt_plus[5,:],color='crimson',alpha=0.2)
ax[1,0].plot(x, july.fmean_rt[5,:].squeeze(), color='deepskyblue', label='July Forecast')
ax[1,0].fill_between(x,july.fvar_rt_minus[5,:],july.fvar_rt_plus[5,:],color='deepskyblue',alpha=0.2)
ax[1,0].plot(x, august.fmean_rt[5,:].squeeze(), color='darkviolet', label='August Forecast')
ax[1,0].fill_between(x,august.fvar_rt_minus[5,:],august.fvar_rt_plus[5,:],color='darkviolet',alpha=0.2)
#ax[1,0].legend(loc='lower left')
ax[1,1].plot(x, SIEs['Laptev_Sea'][0][6:], color='black', label='Laptev Sea')
ax[1,1].plot(x, june.fmean_rt[4,:].squeeze(), color='crimson', label='June Forecast')
ax[1,1].fill_between(x,june.fvar_rt_minus[4,:],june.fvar_rt_plus[4,:],color='crimson',alpha=0.2)
ax[1,1].plot(x, july.fmean_rt[4,:].squeeze(), color='deepskyblue', label='July Forecast')
ax[1,1].fill_between(x,july.fvar_rt_minus[4,:],july.fvar_rt_plus[4,:],color='deepskyblue',alpha=0.2)
ax[1,1].plot(x, august.fmean_rt[4,:].squeeze(), color='darkviolet', label='August Forecast')
ax[1,1].fill_between(x,august.fvar_rt_minus[4,:],august.fvar_rt_plus[4,:],color='darkviolet',alpha=0.2)
#ax[1,1].legend(loc='lower left')
ax[1,2].plot(x, SIEs['East_Siberian_Sea'][0][6:], color='black', label='East Siberian Sea')
ax[1,2].plot(x, june.fmean_rt[3,:].squeeze(), color='crimson', label='June Forecast')
ax[1,2].fill_between(x,june.fvar_rt_minus[3,:],june.fvar_rt_plus[3,:],color='crimson',alpha=0.2)
ax[1,2].plot(x, july.fmean_rt[3,:].squeeze(), color='deepskyblue', label='July Forecast')
ax[1,2].fill_between(x,july.fvar_rt_minus[3,:],july.fvar_rt_plus[3,:],color='deepskyblue',alpha=0.2)
ax[1,2].plot(x, august.fmean_rt[3,:].squeeze(), color='darkviolet', label='August Forecast')
ax[1,2].fill_between(x,august.fvar_rt_minus[3,:],august.fvar_rt_plus[3,:],color='darkviolet',alpha=0.2)
#ax[1,2].legend(loc='lower left')
ax[2,0].plot(x, SIEs['Chukchi_Sea'][0][6:], color='black', label='Chukchi Sea')
ax[2,0].plot(x, june.fmean_rt[2,:].squeeze(), color='crimson', label='June Forecast')
ax[2,0].fill_between(x,june.fvar_rt_minus[2,:],june.fvar_rt_plus[2,:],color='crimson',alpha=0.2)
ax[2,0].plot(x, july.fmean_rt[2,:].squeeze(), color='deepskyblue', label='July Forecast')
ax[2,0].fill_between(x,july.fvar_rt_minus[2,:],july.fvar_rt_plus[2,:],color='deepskyblue',alpha=0.2)
ax[2,0].plot(x, august.fmean_rt[2,:].squeeze(), color='darkviolet', label='August Forecast')
ax[2,0].fill_between(x,august.fvar_rt_minus[2,:],august.fvar_rt_plus[2,:],color='darkviolet',alpha=0.2)
#ax[2,0].legend(loc='lower left')
ax[2,1].plot(x, SIEs['Beaufort_Sea'][0][6:], color='black', label='Beaufort Sea')
ax[2,1].plot(x, june.fmean_rt[1,:].squeeze(), color='crimson', label='June Forecast')
ax[2,1].fill_between(x,june.fvar_rt_minus[1,:],june.fvar_rt_plus[1,:],color='crimson',alpha=0.2)
ax[2,1].plot(x, july.fmean_rt[1,:].squeeze(), color='deepskyblue', label='July Forecast')
ax[2,1].fill_between(x,july.fvar_rt_minus[1,:],july.fvar_rt_plus[1,:],color='deepskyblue',alpha=0.2)
ax[2,1].plot(x, august.fmean_rt[1,:].squeeze(), color='darkviolet', label='August Forecast')
ax[2,1].fill_between(x,august.fvar_rt_minus[1,:],august.fvar_rt_plus[1,:],color='darkviolet',alpha=0.2)
#ax[2,1].legend(loc='lower left')
ax[2,2].plot(x, SIEs['Canadian_Arch'][0][6:], color='black', label='Canadian Arch')
ax[2,2].plot(x, june.fmean_rt[9,:].squeeze(), color='crimson', label='June Forecast')
ax[2,2].fill_between(x,june.fvar_rt_minus[9,:],june.fvar_rt_plus[9,:],color='crimson',alpha=0.2)
ax[2,2].plot(x, july.fmean_rt[9,:].squeeze(), color='deepskyblue', label='July Forecast')
ax[2,2].fill_between(x,july.fvar_rt_minus[9,:],july.fvar_rt_plus[9,:],color='deepskyblue',alpha=0.2)
ax[2,2].plot(x, august.fmean_rt[9,:].squeeze(), color='darkviolet', label='August Forecast')
ax[2,2].fill_between(x,august.fvar_rt_minus[9,:],august.fvar_rt_plus[9,:],color='darkviolet',alpha=0.2)
#ax[2,2].legend(loc='lower left')
plt.rcParams.update({'font.size': 16})
#fig.text(0.5, 0.07, 'Year', ha='center', va='center')
fig.text(0.095, 0.5, 'September Sea Ice Extent (x10\u2076 km\u00b2)', ha='center', va='center', rotation='vertical')
plt.show()
